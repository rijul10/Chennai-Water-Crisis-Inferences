# %% [markdown]
# ## In this notebook i've tried to visualize the data yearly instead of daily to give a broader perspective on the water level in the reservoirs.
#
# The visualization are frugal yet efficient in depicting results.

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the data

# %%
cdata = pd.read_csv("chennai_reservoir_rainfall.csv")
cdata.reset_index(drop=True, inplace=True)

# %%
cdata.tail()
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year Month  \
# 5642  13-06-2019     0.0         0.0       0.0              0.0  2019    06
# 5643  14-06-2019     0.0         0.0       0.0              0.0  2019    06
# 5644  15-06-2019     0.0         0.0       0.0              0.0  2019    06
# 5645  16-06-2019     0.0         0.0       0.0              0.0  2019    06
# 5646  17-06-2019     0.0         0.0       0.0              0.0  2019    06
#
#      Day
# 5642  13
# 5643  14
# 5644  15
# 5645  16
# 5646  17

# %%
cdata.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  5647.000000  5647.000000  5647.000000      5647.000000
# mean      3.364486     3.617177     3.756862         3.923862
# std      12.755029    14.078840    15.060551        16.287227
# min       0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000         0.000000
# 75%       0.000000     0.000000     0.000000         0.000000
# max     300.000000   293.000000   320.000000       475.000000

# %%
cdata.count()
# Out:
# Date               5647
# POONDI             5647
# CHOLAVARAM         5647
# REDHILLS           5647
# CHEMBARAMBAKKAM    5647
# dtype: int64

# %%
cdata.count() - cdata[cdata == 0].count()
# Out:
# Date               5647
# POONDI             1128
# CHOLAVARAM          989
# REDHILLS           1063
# CHEMBARAMBAKKAM    1050
# dtype: int64

# %% [markdown]
# From here we get the idea that POONDI received rainwater for more number of days than the other 3 reservoirs but CHEMBARAMBAKKAM had more amounts of water, albeit for lesser number of days.

# %%
cdata['Year']=[d.split('-')[2] for d in cdata.Date]
cdata['Month']=[d.split('-')[1] for d in cdata.Date]
cdata['Day']=[d.split('-')[0] for d in cdata.Date]

cdata.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year Month Day
# 0  01-01-2004     0.0         0.0       0.0              0.0  2004    01  01
# 1  02-01-2004     0.0         0.0       0.0              0.0  2004    01  02
# 2  03-01-2004     0.0         0.0       0.0              0.0  2004    01  03
# 3  04-01-2004     0.0         0.0       0.0              0.0  2004    01  04
# 4  05-01-2004     0.0         0.0       0.0              0.0  2004    01  05

# %%
bdata = cdata.groupby('Year').sum()

# %% [markdown]
# Calculating the total rainwater collected in the reservoirs per year

# %%
bdata
# Out:
#        POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# Year
# 2004  1099.00      1230.0    1158.4           952.00
# 2005  2031.00      2253.0    2395.5          2428.00
# 2006  1035.00      1330.0    1328.0          1488.00
# 2007  1703.00      1400.0    1531.4          1353.00
# 2008  1524.00      1685.0    1755.0          1578.00
# 2009   982.85      1089.0    1281.0          1542.00
# 2010  1120.50      1914.0    1649.6          1449.00
# 2011  1391.20      1141.2    1515.4          2019.00
# 2012  1100.60       909.0     932.7           824.30
# 2013  1119.00       950.0    1033.4          1262.55
# 2014  1118.60       937.0    1029.4          1233.00
# 2015  2039.10      2150.0    2276.6          2463.00
# 2016   857.60       905.0     873.2          1210.00
# 2017  1134.80      1440.0    1621.4          1618.20
# 2018   706.00      1090.0     833.0           738.00
# 2019    37.00         3.0       1.0             0.00

# %%
from matplotlib import pyplot
sns.lineplot(sns.set(rc={'figure.figsize':(15,8)}), data = bdata)
plt.title('Total Rain fall in the reservoir regions over the years', size = 20)
plt.ylabel('MM', size = 15)
plt.xlabel('Year',size = 15)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ### This is the state of the resevoirs Rainwater level in 2019. An all time low.
# In 2019:-
#
# POONDI with 37 MM of rain water level
#
# CHOLAVARAM with 3 MM of rain water level
#
# REDHILLS with 1 MM of rain water level
#
# CHEMBARAMBAKKAM receiving no rain water
#
# We also observe that there was a steep fall in rainwater levels in 2012 after receiving moderate amounts of rain in 2011. After which the level stayed stagnant till 2014. During 2015, Chennai received huge bouts of rain which resulted in floods which displaced millions.

# %%
rdata = pd.read_csv("chennai_reservoir_levels.csv")

# %%
rdata.tail()
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 5642  13-06-2019    30.0         0.0       0.0              1.0
# 5643  14-06-2019    28.0         0.0       0.0              1.0
# 5644  15-06-2019    27.0         0.0       0.0              1.0
# 5645  16-06-2019    26.0         0.0       0.0              1.0
# 5646  17-06-2019    25.0         0.0       0.0              1.0

# %%
rdata.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  5647.000000  5647.000000  5647.000000      5647.000000
# mean   1133.272203   240.020572  1568.345573      1321.381645
# std    1026.009311   274.601731   890.363617       957.057834
# min       0.900000     0.000000     0.000000         0.000000
# 25%     213.000000    22.300000   849.000000       471.500000
# 50%     782.000000    92.000000  1630.000000      1225.000000
# 75%    2006.000000   460.000000  2236.000000      2083.000000
# max    3231.000000   896.000000  3300.000000      3396.000000

# %%
rdata['Year']=[d.split('-')[2] for d in rdata.Date]
rdata['Month']=[d.split('-')[1] for d in rdata.Date]
rdata['Day']=[d.split('-')[0] for d in rdata.Date]

rdata.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year Month Day
# 0  01-01-2004     3.9         0.0     268.0              0.0  2004    01  01
# 1  02-01-2004     3.9         0.0     268.0              0.0  2004    01  02
# 2  03-01-2004     3.9         0.0     267.0              0.0  2004    01  03
# 3  04-01-2004     3.9         0.0     267.0              0.0  2004    01  04
# 4  05-01-2004     3.8         0.0     267.0              0.0  2004    01  05

# %%
rbdata = rdata.groupby('Year').mean()

# %%
rbdata
# Out:
#            POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# Year
# 2004    77.766967   19.060109   220.899180        68.683060
# 2005   722.680603  147.771781  1468.480712       581.345205
# 2006  1827.553425  484.947945  2044.356164      2075.317808
# 2007  1794.912329  286.391781  2356.654795      1715.126027
# 2008  1862.338798  545.609290  2445.161202      2196.967213
# 2009  1846.221918  414.882110  1969.731205      1795.677123
# 2010  1651.523288  382.175342  2045.271233      2020.501370
# 2011  2399.068493  499.509589  2573.326027      2492.282192
# 2012  1742.816940  225.934426  1872.218579      1571.677596
# 2013   536.953425  100.049315  1324.109589       988.964384
# 2014   311.920548   39.101370  1486.545205       915.958904
# 2015   495.408219  122.278082  1168.942466       881.317808
# 2016  1148.464481  187.158470  1451.043716      1770.989071
# 2017   349.986301  112.753425   491.460274       469.013699
# 2018   641.257534  128.726027  1154.073973       873.315068
# 2019   241.178571   31.255952   381.416667        23.684524

# %%
sns.lineplot(data = rbdata)
plt.title('Mean reservoir water level throughout the years', size = 20)
plt.xlabel('Year', size = 15)
plt.ylabel('Mean mcft', size = 15)
# Out:
# Text(0, 0.5, 'Mean mcft')

# %% [markdown]
# ### Observations
#
# After the year 2011, the reservoir water level in all 4 reservoirs had started depleting.
# However, after receiving heavy amounts of rainfall in 2015, the water level in all the four reservoirs seemed to be approaching normal levels. Until the Chennai drought in 2018, when Chennai received only 835 mm of rainfall, much less than the average 1400 mm. From there, it was only downhill for the water levels in the reservoir.

# %% [markdown]
# ### Comparing the mean reservoir water level with the total rainfall per year:-

# %%
sns.lineplot(data = rbdata['REDHILLS'], label = 'Reservoir Water level')
sns.lineplot(data = bdata['REDHILLS'], label = 'Rainwater Contribution')
plt.title('Mean reservoir water level vs Rainwater contribution in REDHILLS', size = 20)
plt.xlabel('Year', size = 15)
plt.ylabel('Mean mcft & MM', size = 15)
# Out:
# Text(0, 0.5, 'Mean mcft & MM')

# %%
sns.lineplot(data = rbdata['POONDI'], label = 'Reservoir Water level')
sns.lineplot(data = bdata['POONDI'], label = 'Rainwater Contribution')
plt.title('Mean reservoir water level vs Rainwater contribution in POONDI', size = 20)
plt.xlabel('Year', size = 15)
plt.ylabel('Mean mcft & MM', size = 15)
# Out:
# Text(0, 0.5, 'Mean mcft & MM')

# %%
sns.lineplot(data = rbdata['CHOLAVARAM'], label = 'Reservoir Water level')
sns.lineplot(data = bdata['CHOLAVARAM'], label = 'Rainwater Contribution')
plt.title('Mean reservoir water level vs Rainwater contribution in CHOLAVARAM', size = 20)
plt.xlabel('Year', size = 15)
plt.ylabel('Mean mcft & MM', size = 15)
# Out:
# Text(0, 0.5, 'Mean mcft & MM')

# %%
sns.lineplot(data = rbdata['CHEMBARAMBAKKAM'], label = 'Reservoir Water level')
sns.lineplot(data = bdata['CHEMBARAMBAKKAM'], label = 'Rainwater Contribution')
plt.title('Mean reservoir water level vs Rainwater contribution in CHEMBARAMBAKKAM', size = 20)
plt.xlabel('Year', size = 15)
plt.ylabel('Mean mcft & MM', size = 15)
# Out:
# Text(0, 0.5, 'Mean mcft & MM')

# %%
rbdata.plot.bar(stacked=True)
plt.ylabel('Mean reservoir water level in MCft', size = 15)
plt.xlabel('Years', size = 15)
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ### As can be seen from the above bar chart that out of the total capacity of the 4 reservoirs which is 11057 mcft, not even 1/10th of it is filled in 2019 (till June)
#
# Even worse than the drought Chennai received earlier.
